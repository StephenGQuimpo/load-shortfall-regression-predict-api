# %% [markdown]
# # Regression Predict Student Solution
#
# © Explore Data Science Academy
#
# ---
# ### Honour Code
#
# I {**Team ZF4**}, confirm - by submitting this document - that the solutions in this notebook are a result of my own work and that I abide by the [EDSA honour code](https://drive.google.com/file/d/1QDCjGZJ8-FmJE3bZdIQNwnJyQKPhHZBn/view?usp=sharing).
#
# Non-compliance with the honour code constitutes a material breach of contract.
#
# ### Predict Overview: Spain Electricity Shortfall Challenge
#
# The government of Spain is considering an expansion of it's renewable energy resource infrastructure investments. As such, they require information on the trends and patterns of the countries renewable sources and fossil fuel energy generation. Your company has been awarded the contract to:
#
# - 1. analyse the supplied data;
# - 2. identify potential errors in the data and clean the existing data set;
# - 3. determine if additional features can be added to enrich the data set;
# - 4. build a model that is capable of forecasting the three hourly demand shortfalls;
# - 5. evaluate the accuracy of the best machine learning model;
# - 6. determine what features were most important in the model’s prediction decision, and
# - 7. explain the inner working of the model to a non-technical audience.
#
# Formally the problem statement was given to you, the senior data scientist, by your manager via email reads as follow:
#
# > In this project you are tasked to model the shortfall between the energy generated by means of fossil fuels and various renewable sources - for the country of Spain. The daily shortfall, which will be referred to as the target variable, will be modelled as a function of various city-specific weather features such as `pressure`, `wind speed`, `humidity`, etc. As with all data science projects, the provided features are rarely adequate predictors of the target variable. As such, you are required to perform feature engineering to ensure that you will be able to accurately model Spain's three hourly shortfalls.
#
# On top of this, she has provided you with a starter notebook containing vague explanations of what the main outcomes are.

# %% [markdown]
# <a id="cont"></a>
#
# ## Table of Contents
#
# <a href=#one>1. Importing Packages</a>
#
# <a href=#two>2. Loading Data</a>
#
# <a href=#three>3. Exploratory Data Analysis (EDA)</a>
#
# <a href=#four>4. Data Engineering</a>
#
# <a href=#five>5. Modeling</a>
#
# <a href=#six>6. Model Performance</a>
#
# <a href=#seven>7. Model Explanations</a>

# %% [markdown]
#  <a id="one"></a>
# ## 1. Importing Packages
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Importing Packages ⚡ |
# | :--------------------------- |
# | In this section you are required to import, and briefly discuss, the libraries that will be used throughout your analysis and modelling. |
#
# ---

# %%
# Libraries for data loading, data manipulation and data visulisation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

# Libraries for data preparation and model building
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression

# Libraries for model evaluation
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# Libraries for model persistence
import pickle

# Setting global constants to ensure notebook results are reproducible
#PARAMETER_CONSTANT = ###
RANDOM_SPLIT = 1

# %% [markdown]
# <a id="two"></a>
# ## 2. Loading the Data
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Loading the data ⚡ |
# | :--------------------------- |
# | In this section you are required to load the data from the `df_train` file into a DataFrame. |
#
# ---

# %%
df = pd.read_csv('utils/data/df_train.csv')

# %% [markdown]
# <a id="three"></a>
# ## 3. Exploratory Data Analysis (EDA)
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Exploratory data analysis ⚡ |
# | :--------------------------- |
# | In this section, you are required to perform an in-depth analysis of all the variables in the DataFrame. |
#
# ---

# %% [markdown]
# ## Data Dimensions and Columns Exploration

# %%
# Settings to display all columns
pd.set_option('display.max_columns', None)
# View some of the data
df.head()
# Out:
#    Unnamed: 0                 time  Madrid_wind_speed Valencia_wind_deg  \
# 0           0  2015-01-01 03:00:00           0.666667           level_5
# 1           1  2015-01-01 06:00:00           0.333333          level_10
# 2           2  2015-01-01 09:00:00           1.000000           level_9
# 3           3  2015-01-01 12:00:00           1.000000           level_8
# 4           4  2015-01-01 15:00:00           1.000000           level_7
#
#    Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# 0             0.0             0.666667         74.333333        64.000000
# 1             0.0             1.666667         78.333333        64.666667
# 2             0.0             1.000000         71.333333        64.333333
# 3             0.0             1.000000         65.333333        56.333333
# 4             0.0             1.000000         59.000000        57.000000
#
#    Bilbao_clouds_all  Bilbao_wind_speed  Seville_clouds_all  Bilbao_wind_deg  \
# 0                0.0           1.000000                 0.0       223.333333
# 1                0.0           1.000000                 0.0       221.000000
# 2                0.0           1.000000                 0.0       214.333333
# 3                0.0           1.000000                 0.0       199.666667
# 4                2.0           0.333333                 0.0       185.000000
#
#    Barcelona_wind_speed  Barcelona_wind_deg  Madrid_clouds_all  \
# 0              6.333333           42.666667                0.0
# 1              4.000000          139.000000                0.0
# 2              2.000000          326.000000                0.0
# 3              2.333333          273.000000                0.0
# 4              4.333333          260.000000                0.0
#
#    Seville_wind_speed  Barcelona_rain_1h Seville_pressure  Seville_rain_1h  \
# 0            3.333333                0.0             sp25              0.0
# 1            3.333333                0.0             sp25              0.0
# 2            2.666667                0.0             sp25              0.0
# 3            4.000000                0.0             sp25              0.0
# 4            3.000000                0.0             sp25              0.0
#
#    Bilbao_snow_3h  Barcelona_pressure  Seville_rain_3h  Madrid_rain_1h  \
# 0             0.0         1036.333333              0.0             0.0
# 1             0.0         1037.333333              0.0             0.0
# 2             0.0         1038.000000              0.0             0.0
# 3             0.0         1037.000000              0.0             0.0
# 4             0.0         1035.000000              0.0             0.0
#
#    Barcelona_rain_3h  Valencia_snow_3h  Madrid_weather_id  \
# 0                0.0               0.0              800.0
# 1                0.0               0.0              800.0
# 2                0.0               0.0              800.0
# 3                0.0               0.0              800.0
# 4                0.0               0.0              800.0
#
#    Barcelona_weather_id  Bilbao_pressure  Seville_weather_id  \
# 0                 800.0      1035.000000               800.0
# 1                 800.0      1035.666667               800.0
# 2                 800.0      1036.000000               800.0
# 3                 800.0      1036.000000               800.0
# 4                 800.0      1035.333333               800.0
#
#    Valencia_pressure  Seville_temp_max  Madrid_pressure  Valencia_temp_max  \
# 0        1002.666667        274.254667       971.333333         269.888000
# 1        1004.333333        274.945000       972.666667         271.728333
# 2        1005.333333        278.792000       974.000000         278.008667
# 3        1009.000000        285.394000       994.666667         284.899552
# 4                NaN        285.513719      1035.333333         283.015115
#
#    Valencia_temp  Bilbao_weather_id  Seville_temp  Valencia_humidity  \
# 0     269.888000              800.0    274.254667          75.666667
# 1     271.728333              800.0    274.945000          71.000000
# 2     278.008667              800.0    278.792000          65.666667
# 3     284.899552              800.0    285.394000          54.000000
# 4     283.015115              800.0    285.513719          58.333333
#
#    Valencia_temp_min  Barcelona_temp_max  Madrid_temp_max  Barcelona_temp  \
# 0         269.888000          281.013000       265.938000      281.013000
# 1         271.728333          280.561667       266.386667      280.561667
# 2         278.008667          281.583667       272.708667      281.583667
# 3         284.899552          283.434104       281.895219      283.434104
# 4         283.015115          284.213167       280.678437      284.213167
#
#    Bilbao_temp_min  Bilbao_temp  Barcelona_temp_min  Bilbao_temp_max  \
# 0       269.338615   269.338615          281.013000       269.338615
# 1       270.376000   270.376000          280.561667       270.376000
# 2       275.027229   275.027229          281.583667       275.027229
# 3       281.135063   281.135063          283.434104       281.135063
# 4       282.252063   282.252063          284.213167       282.252063
#
#    Seville_temp_min  Madrid_temp  Madrid_temp_min  load_shortfall_3h
# 0        274.254667   265.938000       265.938000        6715.666667
# 1        274.945000   266.386667       266.386667        4171.666667
# 2        278.792000   272.708667       272.708667        4274.666667
# 3        285.394000   281.895219       281.895219        5075.666667
# 4        285.513719   280.678437       280.678437        6620.666667

# %% [markdown]
# We can see that the `Unnamed:0` column contains identical data to the index, so it can be removed from the dataset in the feature engineering section.

# %%
# Check the data types of the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            8763 non-null   int64
#  1   time                  8763 non-null   object
#  2   Madrid_wind_speed     8763 non-null   float64
#  3   Valencia_wind_deg     8763 non-null   object
#  4   Bilbao_rain_1h        8763 non-null   float64
#  5   Valencia_wind_speed   8763 non-null   float64
#  6   Seville_humidity      8763 non-null   float64
#  7   Madrid_humidity       8763 non-null   float64
#  8   Bilbao_clouds_all     8763 non-null   float64
#  9   Bilbao_wind_speed     8763 non-null   float64
#  10  Seville_clouds_all    8763 non-null   float64
#  11  Bilbao_wind_deg       8763 non-null   float64
#  12  Barcelona_wind_speed  8763 non-null   float64
#  13  Barcelona_wind_deg    8763 non-null   float64
#  14  Madrid_clouds_all     8763 non-null   float64
#  15  Seville_wind_speed    8763 non-null   float64
#  16  Barcelona_rain_1h     8763 non-null   float64
#  17  Seville_pressure      8763 non-null   object
#  18  Seville_rain_1h       8763 non-null   float64
#  19  Bilbao_snow_3h        8763 non-null   float64
#  20  Barcelona_pressure    8763 non-null   float64
#  21  Seville_rain_3h       8763 non-null   float64
#  22  Madrid_rain_1h        8763 non-null   float64
#  23  Barcelona_rain_3h     8763 non-null   float64
#  24  Valencia_snow_3h      8763 non-null   float64
#  25  Madrid_weather_id     8763 non-null   float64
#  26  Barcelona_weather_id  8763 non-null   float64
#  27  Bilbao_pressure       8763 non-null   float64
#  28  Seville_weather_id    8763 non-null   float64
#  29  Valencia_pressure     6695 non-null   float64
#  30  Seville_temp_max      8763 non-null   float64
#  31  Madrid_pressure       8763 non-null   float64
#  32  Valencia_temp_max     8763 non-null   float64
#  33  Valencia_temp         8763 non-null   float64
#  34  Bilbao_weather_id     8763 non-null   float64
#  35  Seville_temp          8763 non-null   float64
#  36  Valencia_humidity     8763 non-null   float64
#  37  Valencia_temp_min     8763 non-null   float64
#  38  Barcelona_temp_max    8763 non-null   float64
#  39  Madrid_temp_max       8763 non-null   float64
#  40  Barcelona_temp        8763 non-null   float64
#  41  Bilbao_temp_min       8763 non-null   float64
#  42  Bilbao_temp           8763 non-null   float64
#  43  Barcelona_temp_min    8763 non-null   float64
#  44  Bilbao_temp_max       8763 non-null   float64
#  45  Seville_temp_min      8763 non-null   float64
#  46  Madrid_temp           8763 non-null   float64
#  47  Madrid_temp_min       8763 non-null   float64
#  48  load_shortfall_3h     8763 non-null   float64
# dtypes: float64(45), int64(1), object(3)
# memory usage: 3.3+ MB

# %% [markdown]
# We notice that there are a few `object` data type columns, which we will have to deal with in order to utilise them in the model.
#
# In addition to this, we notice that `Valencia_pressure` has null values.
#
# We will deal with these issues as part of data cleaning before analysing the data statistics in order to get accurate results during the analysis stage.

# %% [markdown]
# ## Data Cleaning
#
# Data cleaning is an essential part of a Data Science project. In order to replicate this part of the cleaning process of the training data in the test data, we will create functions to form part of a bigger data preprocessing function.
#
# ### Dealing with null values
#
# We will start by checking the percentage of nulls contained in `Valencia_pressure`.

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# time                       0
# Madrid_wind_speed          0
# Valencia_wind_deg          0
# Bilbao_rain_1h             0
# Valencia_wind_speed        0
# Seville_humidity           0
# Madrid_humidity            0
# Bilbao_clouds_all          0
# Bilbao_wind_speed          0
# Seville_clouds_all         0
# Bilbao_wind_deg            0
# Barcelona_wind_speed       0
# Barcelona_wind_deg         0
# Madrid_clouds_all          0
# Seville_wind_speed         0
# Barcelona_rain_1h          0
# Seville_pressure           0
# Seville_rain_1h            0
# Bilbao_snow_3h             0
# Barcelona_pressure         0
# Seville_rain_3h            0
# Madrid_rain_1h             0
# Barcelona_rain_3h          0
# Valencia_snow_3h           0
# Madrid_weather_id          0
# Barcelona_weather_id       0
# Bilbao_pressure            0
# Seville_weather_id         0
# Valencia_pressure       2068
# Seville_temp_max           0
# Madrid_pressure            0
# Valencia_temp_max          0
# Valencia_temp              0
# Bilbao_weather_id          0
# Seville_temp               0
# Valencia_humidity          0
# Valencia_temp_min          0
# Barcelona_temp_max         0
# Madrid_temp_max            0
# Barcelona_temp             0
# Bilbao_temp_min            0
# Bilbao_temp                0
# Barcelona_temp_min         0
# Bilbao_temp_max            0
# Seville_temp_min           0
# Madrid_temp                0
# Madrid_temp_min            0
# load_shortfall_3h          0
# dtype: int64

# %%
print('Valencia_pressure percentage of null values is:', round((2068 / df.shape[0]) * 100, 2), '%')
# Out:
# Valencia_pressure percentage of null values is: 23.6 %

# %% [markdown]
# We find that `Valencia_pressure` has 2068 null values. The percentage of null values is 23.6%. For the purposes of data exploration we do not want to drop this feature, and will instead impute either the median, mean, or mode.

# %%
print('Valencia_pressure mean:', df.Valencia_pressure.mean())
print('Valencia_pressure median:', df.Valencia_pressure.median())
print('Valencia_pressure mode: ', df.Valencia_pressure.mode())
# Out:
# Valencia_pressure mean: 1012.0514065222828
# Valencia_pressure median: 1015.0
# Valencia_pressure mode:  0    1018.0
# dtype: float64

# %% [markdown]
# We find the the mean, median, and mode are quite close to each other, so it would be possible to impute any of these values without it affecting the analysis too much.
#
# #### Imputing the mode to `Valencia_pressure`
#
# Before imputing the values, we will first make a copy of our data so that we can keep the original state of our data while we undertake the process of cleaning the data.

# %%
df_clean = df.copy()

# %%
def impute_valencia_pressure_mode(df):
    '''
    Function to impute the mode to the null values of the Valencia_pressure feature.
    
    Parameters:
        df (DataFrame): A Pandas DataFrame containing the data to be cleaned.
    
    Returns:
        df(DataFrame): The same DataFrame object with Valencia_pressure imputed with the mode.
    '''
    
    # impute the null values with the mode
    df['Valencia_pressure'] = df['Valencia_pressure'].fillna(df['Valencia_pressure'].mode()[0])
    
    return df

# %%
df_clean = impute_valencia_pressure_mode(df_clean)

# %% [markdown]
# ### Converting object data types to numeric data
#
# We now consider dealing with the `time`, `Valencia_wind_deg`, and `Seville_pressure` features. We first get a view of the format of the data before considering how best to convert these into numeric data.

# %% [markdown]
# #### Dealing with `time`

# %%
df_clean.time.head(3)
# Out:
# 0    2015-01-01 03:00:00
# 1    2015-01-01 06:00:00
# 2    2015-01-01 09:00:00
# Name: time, dtype: object

# %% [markdown]
# We notice that the `time` data is in a `datetime` format, though stored as an `object` type. We want to convert this to the `datetime` data type in order to do some feature engineering. This process will be handled when we perform feature engineering later.

# %% [markdown]
# #### Dealing with `Valencia_wind_deg`
#
# We first inspect the data format of this feature before deciding how best to transform this data to a numeric data type. We have already seen a sample of the first five entries of the data, which appeared to be in a consistent format: level_number where number is an integer value. We will first inspect the variety of unique values in this column before deciding how best to transform these values.

# %%
df_clean.Valencia_wind_deg.unique()
# Out:
# array(['level_5', 'level_10', 'level_9', 'level_8', 'level_7', 'level_6',
#        'level_4', 'level_3', 'level_1', 'level_2'], dtype=object)

# %% [markdown]
# We see that the format of the values remain constant and contains integers in the range 1-10. This can be used to obtain a numerical categorical feature.

# %%
def convert_valencia_wind_deg(df):
    '''
    Function to convert the Valencia_wind_deg feature to a numerical data type.
    
    Parameters:
        df (DataFrame): A Pandas DataFrame containing the feature to be converted.
        
    Returns:
        df (DataFrame): A Pandas DataFrame with the Valencia_wind_deg feature converted to a numeric data type.
    '''
    
    # extract the numerical part of the string
    df['Valencia_wind_deg'] = df['Valencia_wind_deg'].str.extract('(\d+)')
    # convert the numerical string to numeric data type
    df['Valencia_wind_deg'] = pd.to_numeric(df['Valencia_wind_deg'])
    
    return df

# %%
df_clean = convert_valencia_wind_deg(df_clean)

# %% [markdown]
# #### Dealing with `Seville_pressure`
#
# We first inspect the data format of this feature before deciding how best to transform this data to a numeric data type. We have already seen a sample of the first five entries of the data, which appeared to be in a consistent format: spNumber, where Number is an integer value. We will first inspect the variety of unique values in this column before deciding how best to transform these values.

# %%
df_clean.Seville_pressure.unique()
# Out:
# array(['sp25', 'sp23', 'sp24', 'sp21', 'sp16', 'sp9', 'sp15', 'sp19',
#        'sp22', 'sp11', 'sp8', 'sp4', 'sp6', 'sp13', 'sp17', 'sp20',
#        'sp18', 'sp14', 'sp12', 'sp5', 'sp10', 'sp7', 'sp3', 'sp2', 'sp1'],
#       dtype=object)

# %% [markdown]
# We notice that the values range from sp1 to sp25 and all contain integers after sp. We can use this to extract the numerical part of the value and convert it to numeric data type.

# %%
def convert_seville_pressure(df):
    '''
    Function to convert the Seville_pressure feature to a numerical data type.
    
    Parameters:
        df (DataFrame): A Pandas DataFrame containing the feature to be converted.
        
    Returns:
        df (DataFrame): A Pandas DataFrame with the Seville_pressure feature converted to a numeric data type.
    '''
    
    # extract the numerical part of the string
    df['Seville_pressure'] = df['Seville_pressure'].str.extract('(\d+)')
    # convert the numerical string to numeric data type
    df['Seville_pressure'] = pd.to_numeric(df['Seville_pressure'])
    
    return df

# %%
df_clean = convert_seville_pressure(df_clean)

# %% [markdown]
# ### Removing noise: `Unnamed: 0`
#
# As mentioned before, this column contains exact values contained in the index, and since these are 100% unique values, they do not add any exlanatory power and therefore it is best to remove it from the dataset. We will create a function to do this so that this preprecessing step can be replicated for the test data.

# %%
def remove_unnamed(df):
    '''
    Function to remove the Unnamed: 0 column from the dataset.
    
    Parameters:
        df (DataFrame): The Pandas DataFrame containing the column Unnamed: 0.
        
    Returns:
        df (DataFrame): A Pandas DataFrame without the Unnamed: 0 column.
    '''
    
    df = df.drop(['Unnamed: 0'], axis=1)
    return df

# %%
df_clean = remove_unnamed(df_clean)

# %% [markdown]
# ## Inspect Cleaned Dataset

# %%
df_clean.head()
# Out:
#                   time  Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  \
# 0  2015-01-01 03:00:00           0.666667                  5             0.0
# 1  2015-01-01 06:00:00           0.333333                 10             0.0
# 2  2015-01-01 09:00:00           1.000000                  9             0.0
# 3  2015-01-01 12:00:00           1.000000                  8             0.0
# 4  2015-01-01 15:00:00           1.000000                  7             0.0
#
#    Valencia_wind_speed  Seville_humidity  Madrid_humidity  Bilbao_clouds_all  \
# 0             0.666667         74.333333        64.000000                0.0
# 1             1.666667         78.333333        64.666667                0.0
# 2             1.000000         71.333333        64.333333                0.0
# 3             1.000000         65.333333        56.333333                0.0
# 4             1.000000         59.000000        57.000000                2.0
#
#    Bilbao_wind_speed  Seville_clouds_all  Bilbao_wind_deg  \
# 0           1.000000                 0.0       223.333333
# 1           1.000000                 0.0       221.000000
# 2           1.000000                 0.0       214.333333
# 3           1.000000                 0.0       199.666667
# 4           0.333333                 0.0       185.000000
#
#    Barcelona_wind_speed  Barcelona_wind_deg  Madrid_clouds_all  \
# 0              6.333333           42.666667                0.0
# 1              4.000000          139.000000                0.0
# 2              2.000000          326.000000                0.0
# 3              2.333333          273.000000                0.0
# 4              4.333333          260.000000                0.0
#
#    Seville_wind_speed  Barcelona_rain_1h  Seville_pressure  Seville_rain_1h  \
# 0            3.333333                0.0                25              0.0
# 1            3.333333                0.0                25              0.0
# 2            2.666667                0.0                25              0.0
# 3            4.000000                0.0                25              0.0
# 4            3.000000                0.0                25              0.0
#
#    Bilbao_snow_3h  Barcelona_pressure  Seville_rain_3h  Madrid_rain_1h  \
# 0             0.0         1036.333333              0.0             0.0
# 1             0.0         1037.333333              0.0             0.0
# 2             0.0         1038.000000              0.0             0.0
# 3             0.0         1037.000000              0.0             0.0
# 4             0.0         1035.000000              0.0             0.0
#
#    Barcelona_rain_3h  Valencia_snow_3h  Madrid_weather_id  \
# 0                0.0               0.0              800.0
# 1                0.0               0.0              800.0
# 2                0.0               0.0              800.0
# 3                0.0               0.0              800.0
# 4                0.0               0.0              800.0
#
#    Barcelona_weather_id  Bilbao_pressure  Seville_weather_id  \
# 0                 800.0      1035.000000               800.0
# 1                 800.0      1035.666667               800.0
# 2                 800.0      1036.000000               800.0
# 3                 800.0      1036.000000               800.0
# 4                 800.0      1035.333333               800.0
#
#    Valencia_pressure  Seville_temp_max  Madrid_pressure  Valencia_temp_max  \
# 0        1002.666667        274.254667       971.333333         269.888000
# 1        1004.333333        274.945000       972.666667         271.728333
# 2        1005.333333        278.792000       974.000000         278.008667
# 3        1009.000000        285.394000       994.666667         284.899552
# 4        1018.000000        285.513719      1035.333333         283.015115
#
#    Valencia_temp  Bilbao_weather_id  Seville_temp  Valencia_humidity  \
# 0     269.888000              800.0    274.254667          75.666667
# 1     271.728333              800.0    274.945000          71.000000
# 2     278.008667              800.0    278.792000          65.666667
# 3     284.899552              800.0    285.394000          54.000000
# 4     283.015115              800.0    285.513719          58.333333
#
#    Valencia_temp_min  Barcelona_temp_max  Madrid_temp_max  Barcelona_temp  \
# 0         269.888000          281.013000       265.938000      281.013000
# 1         271.728333          280.561667       266.386667      280.561667
# 2         278.008667          281.583667       272.708667      281.583667
# 3         284.899552          283.434104       281.895219      283.434104
# 4         283.015115          284.213167       280.678437      284.213167
#
#    Bilbao_temp_min  Bilbao_temp  Barcelona_temp_min  Bilbao_temp_max  \
# 0       269.338615   269.338615          281.013000       269.338615
# 1       270.376000   270.376000          280.561667       270.376000
# 2       275.027229   275.027229          281.583667       275.027229
# 3       281.135063   281.135063          283.434104       281.135063
# 4       282.252063   282.252063          284.213167       282.252063
#
#    Seville_temp_min  Madrid_temp  Madrid_temp_min  load_shortfall_3h
# 0        274.254667   265.938000       265.938000        6715.666667
# 1        274.945000   266.386667       266.386667        4171.666667
# 2        278.792000   272.708667       272.708667        4274.666667
# 3        285.394000   281.895219       281.895219        5075.666667
# 4        285.513719   280.678437       280.678437        6620.666667

# %% [markdown]
# It seems the data cleaning process has worked. We have yet to work with our time feature, but for now we will move on to explore some data statistics.

# %% [markdown]
# ## Data Statistics

# %% [markdown]
# ### Look at data statistics

# %%
df_clean.describe()
# Out:
#        Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  \
# count        8763.000000        8763.000000     8763.000000
# mean            2.425729           5.276389        0.135753
# std             1.850371           2.877642        0.374901
# min             0.000000           1.000000        0.000000
# 25%             1.000000           3.000000        0.000000
# 50%             2.000000           5.000000        0.000000
# 75%             3.333333           8.000000        0.100000
# max            13.000000          10.000000        3.000000
#
#        Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# count          8763.000000       8763.000000      8763.000000
# mean              2.586272         62.658793        57.414717
# std               2.411190         22.621226        24.335396
# min               0.000000          8.333333         6.333333
# 25%               1.000000         44.333333        36.333333
# 50%               1.666667         65.666667        58.000000
# 75%               3.666667         82.000000        78.666667
# max              52.000000        100.000000       100.000000
#
#        Bilbao_clouds_all  Bilbao_wind_speed  Seville_clouds_all  \
# count        8763.000000        8763.000000         8763.000000
# mean           43.469132           1.850356           13.714748
# std            32.551044           1.695888           24.272482
# min             0.000000           0.000000            0.000000
# 25%            10.000000           0.666667            0.000000
# 50%            45.000000           1.000000            0.000000
# 75%            75.000000           2.666667           20.000000
# max           100.000000          12.666667           97.333333
#
#        Bilbao_wind_deg  Barcelona_wind_speed  Barcelona_wind_deg  \
# count      8763.000000           8763.000000         8763.000000
# mean        158.957511              2.870497          190.544848
# std         102.056299              1.792197           89.077337
# min           0.000000              0.000000            0.000000
# 25%          73.333333              1.666667          118.166667
# 50%         147.000000              2.666667          200.000000
# 75%         234.000000              4.000000          260.000000
# max         359.333333             12.666667          360.000000
#
#        Madrid_clouds_all  Seville_wind_speed  Barcelona_rain_1h  \
# count        8763.000000         8763.000000        8763.000000
# mean           19.473392            2.425045           0.128906
# std            28.053660            1.672895           0.634730
# min             0.000000            0.000000           0.000000
# 25%             0.000000            1.000000           0.000000
# 50%             0.000000            2.000000           0.000000
# 75%            33.333333            3.333333           0.000000
# max           100.000000           11.666667          12.000000
#
#        Seville_pressure  Seville_rain_1h  Bilbao_snow_3h  Barcelona_pressure  \
# count       8763.000000      8763.000000     8763.000000        8.763000e+03
# mean          13.507246         0.039439        0.031912        1.377965e+03
# std            7.237267         0.175857        0.557264        1.407314e+04
# min            1.000000         0.000000        0.000000        6.706667e+02
# 25%            7.000000         0.000000        0.000000        1.014000e+03
# 50%           14.000000         0.000000        0.000000        1.018000e+03
# 75%           20.000000         0.000000        0.000000        1.022000e+03
# max           25.000000         3.000000       21.300000        1.001411e+06
#
#        Seville_rain_3h  Madrid_rain_1h  Barcelona_rain_3h  Valencia_snow_3h  \
# Bilbao_snow_3h                 0.080180          -0.001642
# Barcelona_pressure             0.037506           0.009572
# Seville_rain_3h                0.009557          -0.026037
# Madrid_rain_1h                 0.089281           0.088502
# Barcelona_rain_3h             -0.041013          -0.038246
# Valencia_snow_3h               0.024339          -0.008114
# Madrid_weather_id             -0.080837          -0.101497
# Barcelona_weather_id          -0.124169          -0.003074
# Bilbao_pressure                0.000377          -0.122915
# Seville_weather_id            -0.033825          -0.086691
# Valencia_pressure             -0.125325           0.017863
# Seville_temp_max              -0.102322           0.103342
# Madrid_pressure               -0.135672           0.075541
# Valencia_temp_max              0.002621           0.091352
# Valencia_temp                 -0.000299           0.093919
# Bilbao_weather_id             -0.536205          -0.031661
# Seville_temp                  -0.095003           0.080357
# Valencia_humidity             -0.129684          -0.279825
# Valencia_temp_min             -0.003806           0.093177
# Barcelona_temp_max            -0.034040           0.011151
# Madrid_temp_max               -0.048491           0.025367
# Barcelona_temp                -0.023171           0.018967
# Bilbao_temp_min               -0.067731           0.107302
# Bilbao_temp                   -0.114118           0.142435
# Barcelona_temp_min            -0.010804           0.023711
# Bilbao_temp_max               -0.158014           0.177123
# Seville_temp_min              -0.077417           0.055077
# Madrid_temp                   -0.046686           0.031245
# Madrid_temp_min               -0.046189           0.021425
# load_shortfall_3h             -0.127293          -0.081602
#
#                       Seville_clouds_all  Bilbao_wind_deg  \
# Madrid_wind_speed               0.191251         0.270950
# Valencia_wind_deg               0.085519         0.157252
# Bilbao_rain_1h                  0.081131         0.279350
# Valencia_wind_speed             0.163675         0.248643
# Seville_humidity                0.399436        -0.087246
# Madrid_humidity                 0.374112        -0.069570
# Bilbao_clouds_all               0.046737         0.280154
# Bilbao_wind_speed               0.127344         0.417534
# Seville_clouds_all              1.000000         0.053482
# Bilbao_wind_deg                 0.053482         1.000000
# Barcelona_wind_speed            0.136591         0.177393
# Barcelona_wind_deg             -0.031373        -0.015481
# Madrid_clouds_all               0.552414         0.085040
# Seville_wind_speed              0.144119         0.120378
# Barcelona_rain_1h               0.003590         0.026187
# Seville_pressure               -0.094748         0.041985
# Seville_rain_1h                 0.408001         0.030082
# Bilbao_snow_3h                  0.001718        -0.041314
# Barcelona_pressure              0.020264         0.034220
# Seville_rain_3h                 0.087240         0.006888
# Madrid_rain_1h                  0.295499         0.057058
# Barcelona_rain_3h               0.029194         0.007202
# Valencia_snow_3h               -0.009782        -0.022680
# Madrid_weather_id              -0.376157        -0.036532
# Barcelona_weather_id           -0.099166        -0.053839
# Bilbao_pressure                -0.330575        -0.107361
# Seville_weather_id             -0.537924        -0.008937
# Valencia_pressure              -0.224108        -0.144920
# Seville_temp_max               -0.181783        -0.076038
# Madrid_pressure                -0.219365        -0.166636
# Valencia_temp_max              -0.188804         0.069642
# Valencia_temp                  -0.186982         0.069065
# Bilbao_weather_id              -0.101888        -0.264719
# Seville_temp                   -0.208859         0.005110
# Valencia_humidity               0.097491        -0.230583
# Valencia_temp_min              -0.179211         0.069433
# Barcelona_temp_max             -0.205060         0.049775
# Madrid_temp_max                -0.238895         0.028535
# Barcelona_temp                 -0.186463         0.068701
# Bilbao_temp_min                -0.134249         0.095047
# Bilbao_temp                    -0.152393         0.065396
# Barcelona_temp_min             -0.153412         0.086482
# Bilbao_temp_max                -0.165567         0.031187
# Seville_temp_min               -0.200453         0.062663
# Madrid_temp                    -0.227094         0.044102
# Madrid_temp_min                -0.212758         0.048397
# load_shortfall_3h              -0.091804        -0.120800
#
#                       Barcelona_wind_speed  Barcelona_wind_deg  \
# Madrid_wind_speed                 0.294640           -0.095380
# Valencia_wind_deg                 0.042795            0.151146
# Bilbao_rain_1h                    0.069997           -0.030723
# Valencia_wind_speed               0.347966           -0.066071
# Seville_humidity                 -0.138625            0.164064
# Madrid_humidity                  -0.058518            0.183725
# Bilbao_clouds_all                 0.094019           -0.065120
# Bilbao_wind_speed                 0.275317           -0.018225
# Seville_clouds_all                0.136591           -0.031373
# Bilbao_wind_deg                   0.177393           -0.015481
# Barcelona_wind_speed              1.000000            0.076376
# Barcelona_wind_deg                0.076376            1.000000
# Madrid_clouds_all                 0.147652           -0.041083
# Seville_wind_speed                0.212193           -0.098837
# Barcelona_rain_1h                 0.042136           -0.037854
# Seville_pressure                 -0.113567            0.199350
# Seville_rain_1h                   0.105892           -0.101449
# Bilbao_snow_3h                    0.015752           -0.023039
# Barcelona_pressure                0.001280           -0.001079
# Seville_rain_3h                   0.058662           -0.043800
# Madrid_rain_1h                    0.130751           -0.112801
# Barcelona_rain_3h                -0.001722           -0.011875
# Valencia_snow_3h                  0.030336           -0.021024
# Madrid_weather_id                -0.106432            0.095456
# Barcelona_weather_id             -0.048004            0.151534
# Bilbao_pressure                  -0.083399            0.123565
# Seville_weather_id               -0.090902            0.068195
# Valencia_pressure                -0.095032            0.096420
# Seville_temp_max                  0.152852           -0.083393
# Madrid_pressure                  -0.020364            0.093900
# Valencia_temp_max                 0.138254           -0.170304
# Valencia_temp                     0.121330           -0.201419
# Bilbao_weather_id                -0.064746            0.049678
# Seville_temp                      0.147628           -0.159882
# Valencia_humidity                -0.249610            0.045277
# Valencia_temp_min                 0.097663           -0.228330
# Barcelona_temp_max                0.114497           -0.151302
# Madrid_temp_max                   0.084209           -0.193487
# Barcelona_temp                    0.116240           -0.189016
# Bilbao_temp_min                   0.123403           -0.182302
# Bilbao_temp                       0.120361           -0.164656
# Barcelona_temp_min                0.109268           -0.226583
# Bilbao_temp_max                   0.109692           -0.147388
# Seville_temp_min                  0.130367           -0.195212
# Madrid_temp                       0.089365           -0.211319
# Madrid_temp_min                   0.084679           -0.211010
# load_shortfall_3h                -0.103633           -0.116133
#
#                       Madrid_clouds_all  Seville_wind_speed  \
# Madrid_wind_speed              0.230126            0.434104
# Valencia_wind_deg              0.105080           -0.007258
# Bilbao_rain_1h                 0.135524            0.140101
# Valencia_wind_speed            0.221887            0.316035
# Seville_humidity               0.366602           -0.202449
# Madrid_humidity                0.484293           -0.125680
# Bilbao_clouds_all              0.109788            0.075066
# Bilbao_wind_speed              0.239326            0.213420
# Seville_clouds_all             0.552414            0.144119
# Bilbao_wind_deg                0.085040            0.120378
# Barcelona_wind_speed           0.147652            0.212193
# Barcelona_wind_deg            -0.041083           -0.098837
# Madrid_clouds_all              1.000000            0.168245
# Seville_wind_speed             0.168245            1.000000
# Barcelona_rain_1h              0.008570            0.074540
# Seville_pressure              -0.068510           -0.185453
# Seville_rain_1h                0.302665            0.125560
# Bilbao_snow_3h                 0.041997            0.046176
# Barcelona_pressure             0.010833           -0.008853
# Seville_rain_3h                0.077246            0.001149
# Madrid_rain_1h                 0.402147            0.177805
# Barcelona_rain_3h             -0.000355           -0.019804
# Valencia_snow_3h               0.023323            0.031472
# Madrid_weather_id             -0.533331           -0.192897
# Barcelona_weather_id          -0.119970           -0.056570
# Bilbao_pressure               -0.323787           -0.132661
# Seville_weather_id            -0.383770           -0.143958
# Valencia_pressure             -0.214663           -0.180165
# Seville_temp_max              -0.190138            0.096339
# Madrid_pressure               -0.190070           -0.136514
# Valencia_temp_max             -0.200774            0.102171
# Valencia_temp                 -0.200355            0.104756
# Bilbao_weather_id             -0.172030           -0.111509
# Seville_temp                  -0.240838            0.139573
# Valencia_humidity              0.066366           -0.217303
# Valencia_temp_min             -0.193107            0.104281
# Barcelona_temp_max            -0.242409            0.068902
# Madrid_temp_max               -0.279732            0.100081
# Barcelona_temp                -0.223940            0.085395
# Bilbao_temp_min               -0.167008            0.093079
# Bilbao_temp                   -0.174079            0.082904
# Barcelona_temp_min            -0.188578            0.097407
# Bilbao_temp_max               -0.172921            0.070808
# Seville_temp_min              -0.245756            0.154254
# Madrid_temp                   -0.262908            0.108460
# Madrid_temp_min               -0.245475            0.089832
# load_shortfall_3h             -0.081623           -0.048433
#
#                       Barcelona_rain_1h  Seville_pressure  Seville_rain_1h  \
# Madrid_wind_speed              0.062758         -0.182792         0.108413
# Valencia_wind_deg              0.000699          0.274340        -0.019783
# Bilbao_rain_1h                 0.052558          0.067471         0.092984
# Valencia_wind_speed            0.031804         -0.065082         0.046085
# Seville_humidity              -0.051022          0.217941         0.227476
# Madrid_humidity               -0.061265          0.294543         0.195455
# Bilbao_clouds_all              0.052913         -0.038859         0.041090
# Bilbao_wind_speed             -0.026640         -0.115875         0.073080
# Seville_clouds_all             0.003590         -0.094748         0.408001
# Bilbao_wind_deg                0.026187          0.041985         0.030082
# Barcelona_wind_speed           0.042136         -0.113567         0.105892
# Barcelona_wind_deg            -0.037854          0.199350        -0.101449
# Madrid_clouds_all              0.008570         -0.068510         0.302665
# Seville_wind_speed             0.074540         -0.185453         0.125560
# Barcelona_rain_1h              1.000000         -0.056790         0.050899
# Seville_pressure              -0.056790          1.000000        -0.190171
# Seville_rain_1h                0.050899         -0.190171         1.000000
# Bilbao_snow_3h                 0.067461          0.028841        -0.004686
# Barcelona_pressure             0.053550          0.020527         0.003875
# Seville_rain_3h               -0.012500         -0.027781        -0.007996
# Madrid_rain_1h                 0.065321         -0.178071         0.343525
# Barcelona_rain_3h             -0.020084          0.022924         0.007454
# Valencia_snow_3h               0.042576          0.003217        -0.003883
# Madrid_weather_id             -0.038090          0.159838        -0.339384
# Barcelona_weather_id          -0.525751          0.152540        -0.159181
# Bilbao_pressure               -0.055521          0.270921        -0.168369
# Seville_weather_id            -0.007767          0.191000        -0.693443
# Seville_temp_min           -0.081794          -0.012016         -0.019706
# Madrid_temp                -0.105667          -0.039565         -0.023734
# Madrid_temp_min            -0.094601          -0.029094         -0.021807
# load_shortfall_3h          -0.027159          -0.024720         -0.021633
#
#                       Madrid_weather_id  Barcelona_weather_id  \
# Madrid_wind_speed             -0.169358             -0.099582
# Valencia_wind_deg             -0.003746             -0.018537
# Bilbao_rain_1h                -0.147768             -0.120618
# Valencia_wind_speed           -0.099056             -0.037605
# Seville_humidity              -0.228442             -0.050515
# Madrid_humidity               -0.341407             -0.051139
# Bilbao_clouds_all             -0.080837             -0.124169
# Bilbao_wind_speed             -0.101497             -0.003074
# Seville_clouds_all            -0.376157             -0.099166
# Bilbao_wind_deg               -0.036532             -0.053839
# Barcelona_wind_speed          -0.106432             -0.048004
# Barcelona_wind_deg             0.095456              0.151534
# Madrid_clouds_all             -0.533331             -0.119970
# Seville_wind_speed            -0.192897             -0.056570
# Barcelona_rain_1h             -0.038090             -0.525751
# Seville_pressure               0.159838              0.152540
# Seville_rain_1h               -0.339384             -0.159181
# Bilbao_snow_3h                 0.000365             -0.033598
# Barcelona_pressure             0.004365             -0.013790
# Seville_rain_3h               -0.129439              0.023488
# Madrid_rain_1h                -0.718816             -0.144551
# Barcelona_rain_3h             -0.006607              0.026554
# Valencia_snow_3h               0.006523             -0.005456
# Madrid_weather_id              1.000000              0.137262
# Barcelona_weather_id           0.137262              1.000000
# Bilbao_pressure                0.245081              0.128763
# Seville_weather_id             0.401143              0.123593
# Valencia_pressure              0.163249              0.096241
# Seville_temp_max               0.103614             -0.000401
# Madrid_pressure                0.098011              0.031370
# Valencia_temp_max              0.103162              0.017432
# Valencia_temp                  0.095043              0.031316
# Bilbao_weather_id              0.160212              0.119813
# Seville_temp                   0.116834              0.014065
# Valencia_humidity             -0.097104             -0.096343
# Valencia_temp_min              0.083657              0.046090
# Barcelona_temp_max             0.105912              0.018332
# Madrid_temp_max                0.149340              0.027375
# Barcelona_temp                 0.085587              0.029239
# Bilbao_temp_min                0.056109              0.053279
# Bilbao_temp                    0.068572              0.053303
# Barcelona_temp_min             0.056176              0.046167
# Bilbao_temp_max                0.076601              0.054720
# Seville_temp_min               0.110713              0.020735
# Madrid_temp                    0.136829              0.025671
# Madrid_temp_min                0.123498              0.026252
# load_shortfall_3h              0.030868              0.063868
#
#                       Bilbao_pressure  Seville_weather_id  Valencia_pressure  \
# Madrid_wind_speed           -0.231747           -0.120014          -0.198631
# Valencia_wind_deg           -0.099051            0.000478          -0.155041
# Bilbao_rain_1h              -0.054814           -0.095723          -0.224834
# Valencia_wind_speed         -0.096374           -0.069092          -0.082930
# Seville_humidity            -0.099458           -0.328265          -0.049493
# Madrid_humidity             -0.053074           -0.291095          -0.088766
# Bilbao_clouds_all            0.000377           -0.033825          -0.125325
# Bilbao_wind_speed           -0.122915           -0.086691           0.017863
# Seville_clouds_all          -0.330575           -0.537924          -0.224108
# Bilbao_wind_deg             -0.107361           -0.008937          -0.144920
# Barcelona_wind_speed        -0.083399           -0.090902          -0.095032
# Barcelona_wind_deg           0.123565            0.068195           0.096420
# Valencia_pressure         -0.016569           0.222325      0.025898
# Seville_temp_max           0.745269           0.221179      0.907261
# Madrid_pressure            0.088261           0.255825      0.150050
# Valencia_temp_max          0.987533           0.112775      0.896059
# Valencia_temp              1.000000           0.106095      0.887040
# Bilbao_weather_id          0.106095           1.000000      0.190360
# Seville_temp               0.887040           0.190360      1.000000
# Valencia_humidity         -0.413654           0.114838     -0.281993
# Valencia_temp_min          0.985479           0.095554      0.852492
# Barcelona_temp_max         0.901400           0.146071      0.866389
# Madrid_temp_max            0.917820           0.153665      0.920908
# Barcelona_temp             0.914601           0.128188      0.852651
# Bilbao_temp_min            0.847584           0.140580      0.818454
# Bilbao_temp                0.854892           0.190635      0.839014
# Barcelona_temp_min         0.874447           0.098428      0.779252
# Bilbao_temp_max            0.833562           0.235183      0.828099
# Seville_temp_min           0.890915           0.145173      0.955160
# Madrid_temp                0.915753           0.143126      0.917075
# Madrid_temp_min            0.871563           0.124199      0.868453
# load_shortfall_3h          0.173225           0.145875      0.159343
#
#                       Valencia_humidity  Valencia_temp_min  \
# Madrid_wind_speed             -0.285787           0.119657
# Valencia_wind_deg             -0.192267          -0.255626
# Bilbao_rain_1h                -0.103868          -0.116835
# Valencia_wind_speed           -0.413017           0.075533
# Seville_humidity               0.464012          -0.657427
# Madrid_humidity                0.378980          -0.689854
# Bilbao_clouds_all             -0.129684          -0.003806
# Bilbao_wind_speed             -0.279825           0.093177
# Seville_clouds_all             0.097491          -0.179211
# Bilbao_wind_deg               -0.230583           0.069433
# Barcelona_wind_speed          -0.249610           0.097663
# Barcelona_wind_deg             0.045277          -0.228330
# Madrid_clouds_all              0.066366          -0.193107
# Seville_wind_speed            -0.217303           0.104281
# Barcelona_rain_1h              0.009027           0.015905
# Seville_pressure              -0.024337          -0.378240
# Seville_rain_1h                0.093558          -0.106177
# Bilbao_snow_3h                -0.048367          -0.089771
# Barcelona_pressure            -0.003012          -0.026596
# Seville_rain_3h                0.031254          -0.059002
# Madrid_rain_1h                 0.073589          -0.064249
# Barcelona_rain_3h              0.002920          -0.055676
# Valencia_snow_3h              -0.019085          -0.026649
# Madrid_weather_id             -0.097104           0.083657
# Barcelona_weather_id          -0.096343           0.046090
# Bilbao_pressure               -0.028138          -0.157873
# Seville_weather_id            -0.132907           0.166209
# Valencia_pressure              0.017142          -0.038113
# Seville_temp_max              -0.214801           0.694121
# Madrid_pressure                0.014234           0.059584
# Valencia_temp_max             -0.399380           0.949377
# Valencia_temp                 -0.413654           0.985479
# Bilbao_weather_id              0.114838           0.095554
# Seville_temp                  -0.281993           0.852492
# Valencia_humidity              1.000000          -0.413537
# Valencia_temp_min             -0.413537           1.000000
# Barcelona_temp_max            -0.221430           0.860510
# Madrid_temp_max               -0.262919           0.893368
# Barcelona_temp                -0.247168           0.892024
# Bilbao_temp_min               -0.271621           0.832773
# Bilbao_temp                   -0.260946           0.832393
# Barcelona_temp_min            -0.266820           0.879687
# Bilbao_temp_max               -0.241397           0.806606
# Seville_temp_min              -0.301694           0.871738
# Madrid_temp                   -0.261356           0.897012
# Madrid_temp_min               -0.247574           0.860347
# load_shortfall_3h              0.043140           0.201863
#
#                       Barcelona_temp_max  Madrid_temp_max  Barcelona_temp  \
# Madrid_wind_speed               0.061854         0.091464        0.080133
# Valencia_wind_deg              -0.260643        -0.341696       -0.260622
# Bilbao_rain_1h                 -0.157326        -0.148397       -0.138901
# Valencia_wind_speed            -0.040998        -0.021970       -0.021456
# Seville_humidity               -0.606770        -0.708937       -0.617797
# Madrid_humidity                -0.691803        -0.803260       -0.684867
# Bilbao_clouds_all              -0.034040        -0.048491       -0.023171
# Bilbao_wind_speed               0.011151         0.025367        0.018967
# Seville_clouds_all             -0.205060        -0.238895       -0.186463
# Bilbao_wind_deg                 0.049775         0.028535        0.068701
# Barcelona_wind_speed            0.114497         0.084209        0.116240
# Barcelona_wind_deg             -0.151302        -0.193487       -0.189016
# Madrid_clouds_all              -0.242409        -0.279732       -0.223940
# Seville_wind_speed              0.068902         0.100081        0.085395
# Barcelona_rain_1h               0.083288         0.079558        0.060384
# Seville_pressure               -0.413186        -0.425754       -0.399793
# Seville_rain_1h                -0.110305        -0.125740       -0.098982
# Bilbao_snow_3h                 -0.087943        -0.084406       -0.086561
# Barcelona_pressure             -0.034412        -0.015984       -0.033221
# Seville_rain_3h                -0.049273        -0.048765       -0.041804
# Madrid_rain_1h                 -0.072734        -0.116052       -0.054825
# Barcelona_rain_3h              -0.051365        -0.046967       -0.042970
# Valencia_snow_3h               -0.029249        -0.024737       -0.029135
# Madrid_weather_id               0.105912         0.149340        0.085587
# Barcelona_weather_id            0.018332         0.027375        0.029239
# Bilbao_pressure                -0.217623        -0.139887       -0.229760
# Seville_weather_id              0.176048         0.193848        0.168608
# Valencia_pressure              -0.003821         0.022654       -0.067210
# Seville_temp_max                0.738489         0.772369        0.693193
# Madrid_pressure                 0.072290         0.092253        0.010542
# Valencia_temp_max               0.918256         0.917838        0.912094
# Valencia_temp                   0.901400         0.917820        0.914601
# Bilbao_weather_id               0.146071         0.153665        0.128188
# Seville_temp                    0.866389         0.920908        0.852651
# Valencia_humidity              -0.221430        -0.262919       -0.247168
# Valencia_temp_min               0.860510         0.893368        0.892024
# Barcelona_temp_max              1.000000         0.906248        0.974480
# Madrid_temp_max                 0.906248         1.000000        0.900428
# Barcelona_temp                  0.974480         0.900428        1.000000
# Bilbao_temp_min                 0.854620         0.865596        0.867434
# Bilbao_temp                     0.867268         0.872234        0.865705
# Barcelona_temp_min              0.885911         0.836680        0.964089
# Bilbao_temp_max                 0.844563         0.846887        0.831470
# Seville_temp_min                0.862597         0.923481        0.873170
# Madrid_temp                     0.896766         0.988871        0.903143
# Madrid_temp_min                 0.847888         0.939147        0.868222
# load_shortfall_3h               0.164734         0.182548        0.182673
#
#                       Bilbao_temp_min  Bilbao_temp  Barcelona_temp_min  \
# Barcelona_rain_1h            0.032362          0.065312     0.075013
# Seville_pressure            -0.359931         -0.385197    -0.418818
# Seville_rain_1h             -0.085650         -0.113038    -0.115727
# Bilbao_snow_3h              -0.105006         -0.075545    -0.081209
# Barcelona_pressure          -0.031854         -0.032889    -0.017886
# Seville_rain_3h             -0.043441         -0.032983    -0.043338
# Madrid_rain_1h              -0.068176         -0.081794    -0.105667
# Barcelona_rain_3h           -0.059089         -0.012016    -0.039565
# Valencia_snow_3h            -0.034205         -0.019706    -0.023734
# Madrid_weather_id            0.076601          0.110713     0.136829
# Barcelona_weather_id         0.054720          0.020735     0.025671
# Bilbao_pressure             -0.221529         -0.150221    -0.156223
# Seville_weather_id           0.132564          0.180721     0.185768
# Valencia_pressure            0.068554         -0.048547    -0.013515
# Seville_temp_max             0.726510          0.743801     0.740831
# Madrid_pressure              0.176838          0.037876     0.054819
# Valencia_temp_max            0.837574          0.886449     0.911331
# Valencia_temp                0.833562          0.890915     0.915753
# Bilbao_weather_id            0.235183          0.145173     0.143126
# Seville_temp                 0.828099          0.955160     0.917075
# Valencia_humidity           -0.241397         -0.301694    -0.261356
# Valencia_temp_min            0.806606          0.871738     0.897012
# Barcelona_temp_max           0.844563          0.862597     0.896766
# Madrid_temp_max              0.846887          0.923481     0.988871
# Barcelona_temp               0.831470          0.873170     0.903143
# Bilbao_temp_min              0.932219          0.847007     0.876185
# Bilbao_temp                  0.981624          0.842972     0.875271
# Barcelona_temp_min           0.764031          0.831689     0.853881
# Bilbao_temp_max              1.000000          0.808278     0.843633
# Seville_temp_min             0.808278          1.000000     0.939079
# Madrid_temp                  0.843633          0.939079     1.000000
# Madrid_temp_min              0.802041          0.907758     0.973641
# load_shortfall_3h            0.180934          0.174718     0.186036
#
#                       Madrid_temp_min  load_shortfall_3h
# Madrid_wind_speed            0.098138          -0.150981
# Valencia_wind_deg           -0.316603          -0.188674
# Bilbao_rain_1h              -0.116431          -0.152510
# Valencia_wind_speed         -0.019742          -0.142791
# Seville_humidity            -0.688664          -0.167290
# Madrid_humidity             -0.759633          -0.150536
# Bilbao_clouds_all           -0.046189          -0.127293
# Bilbao_wind_speed            0.021425          -0.081602
# Seville_clouds_all          -0.212758          -0.091804
# Bilbao_wind_deg              0.048397          -0.120800
# Barcelona_wind_speed         0.084679          -0.103633
# Barcelona_wind_deg          -0.211010          -0.116133
# Madrid_clouds_all           -0.245475          -0.081623
# Seville_wind_speed           0.089832          -0.048433
# Barcelona_rain_1h            0.070146          -0.056633
# Seville_pressure            -0.375249          -0.030434
# Seville_rain_1h             -0.101189          -0.031572
# Bilbao_snow_3h              -0.074892          -0.031721
# Barcelona_pressure          -0.017819          -0.034385
# Seville_rain_3h             -0.035708          -0.032945
# Madrid_rain_1h              -0.094601          -0.027159
# Barcelona_rain_3h           -0.029094          -0.024720
# Valencia_snow_3h            -0.021807          -0.021633
# Madrid_weather_id            0.123498           0.030868
# Barcelona_weather_id         0.026252           0.063868
# Bilbao_pressure             -0.160023           0.039052
# Seville_weather_id           0.174238           0.061104
# Valencia_pressure           -0.047547           0.090405
# Seville_temp_max             0.674561           0.109834
# Madrid_pressure              0.014089           0.092638
# Valencia_temp_max            0.862683           0.144270
# Valencia_temp                0.871563           0.173225
# Bilbao_weather_id            0.124199           0.145875
# Seville_temp                 0.868453           0.159343
# Valencia_humidity           -0.247574           0.043140
# Valencia_temp_min            0.860347           0.201863
# Barcelona_temp_max           0.847888           0.164734
# Madrid_temp_max              0.939147           0.182548
# Barcelona_temp               0.868222           0.182673
# Bilbao_temp_min              0.845799           0.172920
# Bilbao_temp                  0.838195           0.176411
# Barcelona_temp_min           0.838985           0.195984
# Bilbao_temp_max              0.802041           0.180934
# Seville_temp_min             0.907758           0.174718
# Madrid_temp                  0.973641           0.186036
# Madrid_temp_min              1.000000           0.174744
# load_shortfall_3h            0.174744           1.000000

# %% [markdown]
# Based on the data obtained from the correlation matrix above, we find that the current features are not strongly correlated (positive and negative) to the target. This affects the question of **Linearity** between the features and the target. This impacts the choice of a model, because if the relationships are not linear, then a linear regression model will not be suited to this dataset. Furthermore, we inspect the correlation between the features and notice that some features are strongly correlated with each other. This affects the question of **Multicollinearity** between features. We should avoid this and seek to drop the feature that has lower correlation to the target.

# %%
sns.heatmap(corrs, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Exploring Linearity of Features with the Target

# %%
#sns.pairplot(df_clean)

# %% [markdown]
# #### Exploring Multicollinearity between Features
#
# We notice that `Madrid_humidity` and `Seville_humidity` have a correlation of **0.799831**. To explore if this is an issue, we need to consider that these features represent different cities, and so dropping one may not be beneficial to our purpose. Also, we can explore if there is a reason for this fairly strong correlation. If we look at Spain, we notice that Madrid is located 532 km away from Seville. The reason these humidity features may be correlated could be for a variety of geographical reasons.
#
# The heatmap also revealed strong negative correlation between features in the bottom right section of the heatmap. An inspection of the correlation matrix confirms this.

# %% [markdown]
# ### Have a look at feature distributions

# %% [markdown]
# <a id="four"></a>
# ## 4. Data Engineering
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Data engineering ⚡ |
# | :--------------------------- |
# | In this section you are required to: clean the dataset, and possibly create new features - as identified in the EDA phase. |
#
# ---

# %% [markdown]
# Having cleaned the dataset before performing data analysis, we have to ensure that we have all the features we need in order to train the model.

# %% [markdown]
# ## Create new features
#
# In this section we seek to create new features in the dataset.
#
# ### `time` features
#
# We see that the `time` feature contains the `year`, `month`, `day`, and `hour`. The `minutes` and `seconds` values are both zero and can therefore be discarded. In order to make use of the `time` feature, we want to obtain numeric data types since the models we will utilise cannot use `datetime` data. For this reason, we will extract the `year`, `month`, `day`, and `hour` and create seperate columns for each of these. In addition, we will also create new features such as the `weekday` and the `week`.
#
# #### Explanation
#
# The reason why we create additional features such as `weekday` and `week` are because there may be patterns that emerge in relation to the target variable in terms of which day of the week it is or which week of the year it is. This means that we may discover weekly (weekdays vs. weekends) and/or seasonal (summer vs. winter) patterns in relation to the target.

# %%
def get_date_time_features(df):
    '''
    Extracts the year, month, day, and hour from the time feature and creates new columns for them in the DataFrame.
    It also obtains new features (1) weekday and (2) week. These features are inserted at the front of the dataset.
    It then drops the original time feature.
    
    Parameters:
        df (DataFrame): The Pandas DataFrame containing the data to be cleaned.
        
    Returns:
        df(DataFrame): The same DataFrame with time feature dropped and new columns for year, month, day, hour, weekday, week.
    '''
    
    # convert time feature to datetime data type
    df['time'] = pd.to_datetime(df['time'])
    
    # obtain new features from the time feature and insert them at the beginning of the dataset
    df.insert(1, 'year', df['time'].dt.year)
    df.insert(2, 'month', df['time'].dt.month)
    df.insert(3, 'day', df['time'].dt.day) # day of the month
    df.insert(4, 'hour', df['time'].dt.hour)
    df.insert(5, 'week', df['time'].dt.isocalendar().week) # week of the year
    df.insert(6, 'weekday', df['time'].dt.weekday + 1) # day of the week: Monday is 1, Sunday is 7
    
    # we now drop the time column
    df = df.drop(['time'], axis=1)
    
    return df

# %%
df_clean = get_date_time_features(df_clean)

# %%
# inspect the new dataframe
df_clean.head()
# Out:
#    year  month  day  hour  week  weekday  Madrid_wind_speed  \
# 0  2015      1    1     3     1        4           0.666667
# 1  2015      1    1     6     1        4           0.333333
# 2  2015      1    1     9     1        4           1.000000
# 3  2015      1    1    12     1        4           1.000000
# 4  2015      1    1    15     1        4           1.000000
#
#    Valencia_wind_deg  Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  \
# 0                  5             0.0             0.666667         74.333333
# 1                 10             0.0             1.666667         78.333333
# 2                  9             0.0             1.000000         71.333333
# 3                  8             0.0             1.000000         65.333333
# 4                  7             0.0             1.000000         59.000000
#
#    Madrid_humidity  Bilbao_clouds_all  Bilbao_wind_speed  Seville_clouds_all  \
# 0        64.000000                0.0           1.000000                 0.0
# 1        64.666667                0.0           1.000000                 0.0
# 2        64.333333                0.0           1.000000                 0.0
# 3        56.333333                0.0           1.000000                 0.0
# 4        57.000000                2.0           0.333333                 0.0
#
#    Bilbao_wind_deg  Barcelona_wind_speed  Barcelona_wind_deg  \
# 0       223.333333              6.333333           42.666667
# 1       221.000000              4.000000          139.000000
# 2       214.333333              2.000000          326.000000
# 3       199.666667              2.333333          273.000000
# 4       185.000000              4.333333          260.000000
#
#    Madrid_clouds_all  Seville_wind_speed  Barcelona_rain_1h  Seville_pressure  \
# 0                0.0            3.333333                0.0                25
# 1                0.0            3.333333                0.0                25
# 2                0.0            2.666667                0.0                25
# 3                0.0            4.000000                0.0                25
# 4                0.0            3.000000                0.0                25
#
#    Seville_rain_1h  Bilbao_snow_3h  Barcelona_pressure  Seville_rain_3h  \
# 0              0.0             0.0         1036.333333              0.0
# 1              0.0             0.0         1037.333333              0.0
# 2              0.0             0.0         1038.000000              0.0
# 3              0.0             0.0         1037.000000              0.0
# 4              0.0             0.0         1035.000000              0.0
#
#    Madrid_rain_1h  Barcelona_rain_3h  Valencia_snow_3h  Madrid_weather_id  \
# 0             0.0                0.0               0.0              800.0
# 1             0.0                0.0               0.0              800.0
# 2             0.0                0.0               0.0              800.0
# 3             0.0                0.0               0.0              800.0
# 4             0.0                0.0               0.0              800.0
#
#    Barcelona_weather_id  Bilbao_pressure  Seville_weather_id  \
# 0                 800.0      1035.000000               800.0
# 1                 800.0      1035.666667               800.0
# 2                 800.0      1036.000000               800.0
# 3                 800.0      1036.000000               800.0
# 4                 800.0      1035.333333               800.0
#
#    Valencia_pressure  Seville_temp_max  Madrid_pressure  Valencia_temp_max  \
# 0        1002.666667        274.254667       971.333333         269.888000
# 1        1004.333333        274.945000       972.666667         271.728333
# 2        1005.333333        278.792000       974.000000         278.008667
# 3        1009.000000        285.394000       994.666667         284.899552
# 4        1018.000000        285.513719      1035.333333         283.015115
#
#    Valencia_temp  Bilbao_weather_id  Seville_temp  Valencia_humidity  \
# 0     269.888000              800.0    274.254667          75.666667
# 1     271.728333              800.0    274.945000          71.000000
# 2     278.008667              800.0    278.792000          65.666667
# 3     284.899552              800.0    285.394000          54.000000
# 4     283.015115              800.0    285.513719          58.333333
#
#    Valencia_temp_min  Barcelona_temp_max  Madrid_temp_max  Barcelona_temp  \
# 0         269.888000          281.013000       265.938000      281.013000
# 1         271.728333          280.561667       266.386667      280.561667
# 2         278.008667          281.583667       272.708667      281.583667
# 3         284.899552          283.434104       281.895219      283.434104
# 4         283.015115          284.213167       280.678437      284.213167
#
#    Bilbao_temp_min  Bilbao_temp  Barcelona_temp_min  Bilbao_temp_max  \
# 0       269.338615   269.338615          281.013000       269.338615
# 1       270.376000   270.376000          280.561667       270.376000
# 2       275.027229   275.027229          281.583667       275.027229
# 3       281.135063   281.135063          283.434104       281.135063
# 4       282.252063   282.252063          284.213167       282.252063
#
#    Seville_temp_min  Madrid_temp  Madrid_temp_min  load_shortfall_3h
# 0        274.254667   265.938000       265.938000        6715.666667
# 1        274.945000   266.386667       266.386667        4171.666667
# 2        278.792000   272.708667       272.708667        4274.666667
# 3        285.394000   281.895219       281.895219        5075.666667
# 4        285.513719   280.678437       280.678437        6620.666667

# %%
# engineer existing features

# %% [markdown]
# <a id="five"></a>
# ## 5. Modelling
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Modelling ⚡ |
# | :--------------------------- |
# | In this section, you are required to create one or more regression models that are able to accurately predict the thee hour load shortfall. |
#
# ---

# %%
# create targets and features dataset
X = df_clean.drop('load_shortfall_3h', axis=1)
y = df_clean['load_shortfall_3h']

# %% [markdown]
# #### Scaling the Data using Standardisation
#
# When inspecting the range of values and the respective scales used in the different features, we notice that there is a large discrepency. For this reason, we implement scaling in order to perform regularisation on the data and to be able to compare the relative influence of each feature on the target when making predictions.
#
# We will use Z-score standardisation instead of normalisation since it is robust to outliers and takes into consideration the distribution of the feature.

# %%
# standardise the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# View the scaled data
X_scaled.head()
# Out:
#        year     month       day      hour      week  weekday  \
# 0 -1.226179 -1.602429 -1.675368 -1.090901 -1.709703 -0.00274
# 1 -1.226179 -1.602429 -1.675368 -0.654451 -1.709703 -0.00274
# 2 -1.226179 -1.602429 -1.675368 -0.218001 -1.709703 -0.00274
# 3 -1.226179 -1.602429 -1.675368  0.218449 -1.709703 -0.00274
# 4 -1.226179 -1.602429 -1.675368  0.654899 -1.709703 -0.00274
#
#    Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  Valencia_wind_speed  \
# 
#
#    Barcelona_temp  Bilbao_temp_min  Bilbao_temp  Barcelona_temp_min  \
# 0       -1.354598        -2.338357    -2.505658           -1.218309
# 1       -1.423738        -2.183645    -2.353511           -1.292271
# 2       -1.267176        -1.489980    -1.671342           -1.124792
# 3       -0.983703        -0.579082    -0.775541           -0.821553
# 4       -0.864356        -0.412497    -0.611717           -0.693885
#
#    Bilbao_temp_max  Seville_temp_min  Madrid_temp  Madrid_temp_min
# 0        -2.621665         -2.125118    -2.405393        -2.309892
# 1        -2.475661         -2.040702    -2.357388        -2.261154
# 2        -1.821036         -1.570279    -1.680968        -1.574407
# 3        -0.961406         -0.762967    -0.698057        -0.576488
# 4        -0.804197         -0.748327    -0.828246        -0.708665

# %%
# split data into training and validation sets
# we will not use random sampling as the chronology of time is an important factor
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size=0.2, shuffle=False)

# %%
X_train.shape
# Out:
# (7010, 52)

# %% [markdown]
# ### Model Training
#
# We will choose linear models since these models are more interpretable as to the features that have more or less influence on the target. We will implement Linear Regression, Ridge Regression, and LASSO regression.

# %%
# Initialise the models
lm = LinearRegression()
ridge = Ridge()
lasso = Lasso(alpha=0.015, tol=1e-2, normalize=True)

# %%
# train the models
lm.fit(X_train, y_train)
ridge.fit(X_train, y_train)
lasso.fit(X_train, y_train)
# Out:
# C:\Users\Stephen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19629552944.33737, tolerance: 1863444199.3152137
#   positive)
# Lasso(alpha=0.015, normalize=True, tol=0.01)

# %%
# Predictions on the training set
train_lm_pred = lm.predict(X_train)
train_ridge_pred = ridge.predict(X_train)
train_lasso_pred = lasso.predict(X_train)

# %% [markdown]
# ### Training Evaluation
#
# We want to explore the result of training, especially with reference to the regularised models. In particular, we want to explore the subset selection of the LASSO model and seek to use this insight.

# %%
# Examing training results: MSE and R2
train_results_dict = {'Training RMSE':{'Linear Regression':np.sqrt(mean_squared_error(y_train, train_lm_pred)),
                                     'Ridge':np.sqrt(mean_squared_error(y_train, train_ridge_pred)),
                                     'Lasso':np.sqrt(mean_squared_error(y_train, train_lasso_pred))
                                     },
                     'Training R2:':{'Linear Regression':r2_score(y_train, train_lm_pred),
                                    'Ridge':r2_score(y_train, train_ridge_pred),
                                    'Lasso':r2_score(y_train, train_lasso_pred)
                                    }
                     }

train_results_df = pd.DataFrame(data=train_results_dict)
train_results_df
# Out:
#                    Training RMSE  Training R2:
# Linear Regression    4694.152489      0.171074
# Ridge                4694.422530      0.170978
# Lasso                4696.528877      0.170234

# %% [markdown]
# We see that on the training set, the Linear Regression has a lower MSE and higher R2 than both the Ridge and Lasso models. This may seem to indicate that the Linear Regression model is the best of the three, but we need to evaluate the performance on unseen data before making this conclusion. The reason for this is that we do not know if the Linear Regression model has overfit on the training data. In order to evaluate which model generalises better, we need to use the validation set.

# %%
# Explore intercepts of each model
lm_b0 = float(lm.intercept_)
ridge_b0 = float(ridge.intercept_)
lasso_b0 = float(lasso.intercept_)

print('Linear Regression Intercept:\t', lm_b0)
print('Ridge Intercept:\t\t', ridge_b0)
print('Lasso Intercept:\t\t', lasso_b0)
# Out:
# Linear Regression Intercept:	 10391.069579705276
# Ridge Intercept:		 10396.407162213853
# Lasso Intercept:		 10407.558225969062

# %%
# Explore coefficients of each model
lm_coef_df = pd.DataFrame(lm.coef_, X.columns, columns=['Linear Regression Coefficients'])
ridge_coef_df = pd.DataFrame(ridge.coef_, X.columns, columns=['Ridge Coefficients'])
lasso_coef_df = pd.DataFrame(lasso.coef_, X.columns, columns=['Lasso Coefficients'])

coef_df_list = [lm_coef_df, ridge_coef_df, lasso_coef_df]
coef_df = pd.concat(coef_df_list, axis=1)
coef_df
# Out:
#                       Linear Regression Coefficients  Ridge Coefficients  \
# year                                     -136.238197         -126.999606
# month                                     151.622236          155.311920
# day                                       345.003291          341.872357
# hour                                      622.718477          622.808189
# week                                      118.208199          119.551529
# weekday                                  -724.246646         -724.192821
# Madrid_wind_speed                        -423.596563         -420.367890
# Valencia_wind_deg                        -153.612408         -154.495950
# Bilbao_rain_1h                           -196.398208         -198.216140
# Valencia_wind_speed                      -123.007796         -119.266450
# Seville_humidity                         -762.255957         -759.878511
# Madrid_humidity                          -200.804478         -209.907721
# Bilbao_clouds_all                        -116.294302         -115.729572
# Bilbao_wind_speed                         -69.736953          -69.637950
# Seville_clouds_all                        137.753009          135.599800
# Bilbao_wind_deg                          -360.951742         -358.915097
# Barcelona_wind_speed                     -160.161763         -161.349480
# Barcelona_wind_deg                       -150.034022         -152.968742
# Madrid_clouds_all                         249.905766          252.390057
# Seville_wind_speed                        -19.421194          -17.497647
# Barcelona_rain_1h                        -116.137338         -116.084699
# Seville_pressure                          580.657155          574.926576
# Seville_rain_1h                           163.224807          161.922249
# Bilbao_snow_3h                             62.051592           62.063867
# Barcelona_pressure                        -66.276440          -66.409151
# Seville_rain_3h                          -111.097019         -111.972996
# Madrid_rain_1h                             56.669145           54.693820
# Barcelona_rain_3h                         -81.231846          -82.117056
# Valencia_snow_3h                          -57.229686          -57.416570
# Madrid_weather_id                         -41.954909          -44.017970
# Barcelona_weather_id                       54.575733           57.429539
# Bilbao_pressure                          -308.193369         -298.512153
# Seville_weather_id                         47.568149           46.731680
# Valencia_pressure                         435.978923          434.784911
# Seville_temp_max                        -1159.886321         -919.874482
# Madrid_pressure                            20.363317           20.837848
# Valencia_temp_max                        -939.662397        -1035.649188
# Valencia_temp                           -1860.226354        -1631.619511
# Bilbao_weather_id                          72.507669           71.501046
# Seville_temp                             3478.441585         2898.735065
# Valencia_humidity                         652.222527          663.838926
# Valencia_temp_min                        3186.378671         3074.822796
# Barcelona_temp_max                      -1051.379100         -977.409577
# Madrid_temp_max                         -3381.651398        -3271.212444
# Barcelona_temp                           3016.393305         2813.641198
# Bilbao_temp_min                          4160.747026         3584.496554
# Bilbao_temp                             -8148.659308        -7019.559253
# Barcelona_temp_min                      -1102.127179         -993.230997
# Bilbao_temp_max                          3881.487201         3326.787034
# Seville_temp_min                        -3280.579510        -2904.627555
# Madrid_temp                              5531.527376         5332.825414
# Madrid_temp_min                         -2101.223676        -2025.905535
#
#                       Lasso Coefficients
# year                         -107.046201
# month                         153.449619
# day                           334.796661
# hour                          622.032559
# week                          129.276017
# weekday                      -723.079483
# Madrid_wind_speed            -415.758614
# Valencia_wind_deg            -156.198169
# Bilbao_rain_1h               -200.947143
# Valencia_wind_speed          -112.991419
# Seville_humidity             -757.150286
# Madrid_humidity              -204.356602
# Bilbao_clouds_all            -115.441984
# Bilbao_wind_speed             -66.839401
# Seville_clouds_all            130.334712
# Bilbao_wind_deg              -353.750549
# Barcelona_wind_speed         -164.751192
# Barcelona_wind_deg           -155.982350
# Madrid_clouds_all             247.682568
# Seville_wind_speed            -10.944846
# Barcelona_rain_1h            -116.075796
# Seville_pressure              566.669613
# Seville_rain_1h               157.200223
# Bilbao_snow_3h                 61.111842
# Barcelona_pressure            -65.889225
# Seville_rain_3h              -111.577148
# Madrid_rain_1h                 50.575245
# Barcelona_rain_3h             -82.044907
# Valencia_snow_3h              -55.898600
# Madrid_weather_id             -46.229547
# Barcelona_weather_id           60.828629
# Bilbao_pressure              -274.043993
# Seville_weather_id             41.175759
# Valencia_pressure             430.389488
# Seville_temp_max             -104.247799
# Madrid_pressure                20.623569
# Valencia_temp_max           -1307.669966
# Valencia_temp                -963.128590
# Bilbao_weather_id              68.871167
# Seville_temp                  995.763777
# Valencia_humidity             682.430560
# Valencia_temp_min            2708.471740
# Barcelona_temp_max           -637.190802
# Madrid_temp_max             -3281.650237
# Barcelona_temp               2080.330311
# Bilbao_temp_min              2676.085342
# Bilbao_temp                 -5292.952995
# Barcelona_temp_min           -621.164500
# Bilbao_temp_max              2492.480404
# Seville_temp_min            -1725.446775
# Madrid_temp                  5347.163335
# Madrid_temp_min             -1990.915372

# %%
# plot training predictions vs. actual training target
fig, axs = plt.subplots(1, 3, figsize=(15, 4), sharey=True)
fig.suptitle('Training Predictions vs. Training Targets')
axs[0].plot(np.arange(len(y_train)), y_train, label='Target')
axs[0].plot(np.arange(len(y_train)), train_lm_pred, label='Linear Regression')
axs[0].legend()
axs[1].plot(np.arange(len(y_train)), y_train, label='Target')
axs[1].plot(np.arange(len(y_train)), train_ridge_pred, label='Ridge', color='r')
axs[1].legend()
axs[2].plot(np.arange(len(y_train)), y_train, label='Target')
axs[2].plot(np.arange(len(y_train)), train_lasso_pred, label='Lasso', color='g')
axs[2].legend()
plt.show()

# %% [markdown]
# <a id="six"></a>
# ## 6. Model Performance
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Model performance ⚡ |
# | :--------------------------- |
# | In this section you are required to compare the relative performance of the various trained ML models on a holdout dataset and comment on what model is the best and why. |
#
# ---

# %% [markdown]
# In this section we will do the following:
# - Compare model performance
# - Choose the best model and motivate why it is the best choice
# - Save the chosen model

# %% [markdown]
# ### Compare model performance
#
# We make predictions on the validation set and then compare the MSE and R2 scores for each model

# %%
# Predictions on validation set
val_lm_pred = lm.predict(X_val)
val_ridge_pred = lm.predict(X_val)
val_lasso_pred = lasso.predict(X_val)

# %%
# plot validation predictions vs. actual validation targets
fig, axs = plt.subplots(1, 3, figsize=(15, 4), sharey=True)
fig.suptitle('Validation Predictions vs. Validation Targets')
axs[0].plot(np.arange(len(y_val)), y_val, label='Target')
axs[0].plot(np.arange(len(y_val)), val_lm_pred, label='Linear Regression')
axs[0].legend()
axs[1].plot(np.arange(len(y_val)), y_val, label='Target')
axs[1].plot(np.arange(len(y_val)), val_ridge_pred, label='Ridge', color='r')
axs[1].legend()
axs[2].plot(np.arange(len(y_val)), y_val, label='Target')
axs[2].plot(np.arange(len(y_val)), val_lasso_pred, label='Lasso', color='g')
axs[2].legend()
plt.show()

# %%
# Examing validation results: MSE and R2
val_results_dict = {'Validation RMSE':{'Linear Regression':np.sqrt(mean_squared_error(y_val, val_lm_pred)),
                                     'Ridge':np.sqrt(mean_squared_error(y_val, val_ridge_pred)),
                                     'Lasso':np.sqrt(mean_squared_error(y_val, val_lasso_pred))
                                     },
                     'Validation R2:':{'Linear Regression':r2_score(y_val, val_lm_pred),
                                    'Ridge':r2_score(y_val, val_ridge_pred),
                                    'Lasso':r2_score(y_val, val_lasso_pred)
                                    }
                     }

val_results_df = pd.DataFrame(data=val_results_dict)
val_results_df
# Out:
#                    Validation RMSE  Validation R2:
# Linear Regression      4771.788421        0.042557
# Ridge                  4771.788421        0.042557
# Lasso                  4749.164390        0.051615

# %% [markdown]
# ### Choose best model and motivate why it is the best choice
#
# Although these are very bad MSE and R2 scores, we can still make a few comparisons between the training and validation scores.
# - The Linear Regression performed best on the training set
# - The Lasso Regression performed best on the validation set
# This shows that the Linear regression model overfitted the training data more than the Lasso model.
# More work needs to be done to achive a lower MSE and higher R2 score.
#
# **Best Model: Lasso**
# - Lasso has a lower MSE and higher R2 than the Linear Regression and Ridge models on the validation set
# - Generalises better to unseen data than the Linear Regression and Ridge models

# %% [markdown]
# ### Saving the chosen model
#
# We will save the Lasso model as a .pkl file. Alongside this, we will also ensure to have a .txt file that contains the following:
# - Python environment dependencies (versions of Python packages)
# - Python version
#
# This is to ensure that the behaviour of the model is reproducible after serialization.

# %%
model_save_path = 'assets/trained-models/lasso_model.pkl'
with open(model_save_path, 'wb') as file:
    pickle.dump(lasso, file)

# %% [markdown]
# ### Generating a Kaggle Submission
#
# Here we will run code to generate a `submission.csv` file for the purposes of submitting our predictions to the kaggle competition. This is will invlove a number of steps:
#
#     1) Retrain the chosen model on the entire training set without keeping a validation set aside
#     2) Run the preprocessing on the test set to get it into the same format as the training data
#     3) Get predictions on the test data
#     4) Create a new DataFrame with the Predictions made according to Time
#     5) Save the DataFrame to a csv file.

# %%
lasso.fit(X_scaled, y)
# Out:
# C:\Users\Stephen\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20213662860.75403, tolerance: 2385718085.019668
#   positive)
# Lasso(alpha=0.015, normalize=True, tol=0.01)

# %%
def preprocessing(df):
    '''
    Function to implement the required preprocessing steps on the test data.
    
    Parameters:
        df (DataFrame): A Pandas DataFrame containing the test data to preprocess.
        
    Returns:
        X (DataFrame): A Pandas DataFrame with the required test data preprocessing complete.
    '''
    
    df = impute_valencia_pressure_mode(df)
    df = convert_valencia_wind_deg(df)
    df = convert_seville_pressure(df)
    df = remove_unnamed(df)
    df = get_date_time_features(df)
    X_scaled = scaler.fit_transform(df)
    X = pd.DataFrame(X_scaled, columns=df.columns)
    
    return X

# %%
df_test = pd.read_csv('utils/data/df_test.csv')
X = preprocessing(df_test)

# %%
y_pred = lasso.predict(X)

# %%
df_pred = pd.DataFrame(y_pred, columns=['load_shortfall_3h'])
output_df = pd.DataFrame({'time':df_test['time']})
submission_df = output_df.join(df_pred)
submission_df.to_csv('utils/data/submission.csv', index=False)

# %% [markdown]
# <a id="seven"></a>
# ## 7. Model Explanations
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Model explanation ⚡ |
# | :--------------------------- |
# | In this section, you are required to discuss how the best performing model works in a simple way so that both technical and non-technical stakeholders can grasp the intuition behind the model's inner workings. |
#
# ---

# %% [markdown]
# ## How the Lasso Regression Model Works
